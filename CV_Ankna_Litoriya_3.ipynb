# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io
import cv2

url="https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg"
imge = io.imread(url)

image = np.array(imge)

print("The loaded image is of type:",type(image))
print("The loaded image is of size:",image.shape)
print("intensity at index", image[50][50])

B,G,R = cv2.split(image)
#cv2.imshow("Image",image)
#cv2.imshow("B",B)
#cv2.imshow("G",G)
#cv2.imshow("R",R)

gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#cv2.imshow("Gray",gray)
hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
h,s,v=cv2.split(hsv)
hsv_equ=cv2.equalizeHist(v)
merge_hsv=cv2.merge((h,s,hsv_equ))
bgr_enhanced=cv2.cvtColor(merge_hsv,cv2.COLOR_HSV2BGR)

hist=cv2.calcHist([image],channels=[0],mask=None,histSize=[256],ranges=[0,255])
B_hist=cv2.calcHist([B],channels=[0],mask=None,histSize=[256],ranges=[0,255])
G_hist=cv2.calcHist([G],channels=[0],mask=None,histSize=[256],ranges=[0,255])
R_hist=cv2.calcHist([R],channels=[0],mask=None,histSize=[256],ranges=[0,255])

output=cv2.equalizeHist(gray)
output_clr=cv2.cvtColor(output,cv2.COLOR_GRAY2BGR)
color_enhanced = cv2.applyColorMap(gray, cv2.COLORMAP_JET)

#hsv_equ=cv2.equalizeHist(hsv)
cv2.imshow("BGR_ENH",bgr_enhanced)
cv2.imshow("Original",image)
cv2.imshow("gray_Enh",output)
#cv2.imshow("Output",np.hstack([gray, output]))
#cv2.imshow("hsv_value",hsv_equ)

image_hist=cv2.calcHist([output],channels=[0],mask=None,histSize=[256],ranges=[0,255])

plt.plot(B_hist)
plt.plot(G_hist)
plt.plot(R_hist)
#plt.plot(image_hist)
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

import cv2
import numpy as np
#image=cv2.imread(r"C:\Users\cheta\OneDrive\Desktop\depositphotos_74355965-stock-photo-beau
tiful-oak-at-the-sunset.jpg")
image=cv2.imread(r"C:\Users\cheta\OneDrive\Pictures\Camera
Roll\WIN_20230320_00_08_27_Pro.jpg")

#video=cv2.VideoCapture(r"C:\Users\cheta\OneDrive\Pictures\Camera
Roll\WIN_20230823_16_29_45_Pro.mp4")
#success,image=video.read()
#while success:
# success,image=video.read()
# frame=cv2.resize(image,(680,700))
#cv2.imshow("VIDEO",frame)

# if cv2.waitKey(1)==27:
# break

gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

## Bluring
blur=cv2.blur(image,(5,5))
gaussian_blur = cv2.GaussianBlur(image, (5, 5), 2)
median_blur = cv2.medianBlur(image, 7)
bilateral_filter = cv2.bilateralFilter(image, 9, 75, 75) ## Bluring while preserving the edges

# Resize
# Resize the image to a new width and height
gray = cv2.resize(gray, (600, 600))

# Cropping
# Define the coordinates of the ROI
x, y, w, h = 100, 50, 200, 900

cropped = image[y:y+h, x:x+w]

# Rotation
# Get the image center
h,w = (image.shape[:2])

center=(h/2,w/2)
# Define the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1 )
# Apply the rotation
rotated = cv2.warpAffine(image, rotation_matrix, (952, 830 ))

# Flipping the Image
flipped_horizontal=cv2.flip(image,1)

# Morphological Transformation
kernal=np.ones((5,5))
erosion=cv2.erode(gray,kernal,iterations=1)# ek black to sare balck , will consider white only if
surrounding is also white
dilate=cv2.dilate(gray,kernal,iterations=1)# Ek white to sare white
opening=cv2.morphologyEx(gray,cv2.MORPH_OPEN,kernal)# Errosion then Dilation TO reduce
Noise
closing=cv2.morphologyEx(gray,cv2.MORPH_CLOSE,kernal)#dilation then erosion # image ko
bharne ke liye
GradientOperation=cv2.morphologyEx(gray,cv2.MORPH_GRADIENT,kernal)#Dilation - Erode,Mote
- Patla Outline OF The Object
TOP_HAT=cv2.morphologyEx(gray,cv2.MORPH_TOPHAT,kernal)#input-Opening Heighlight minor
detaion in the image only
cv2.imshow("GradientOperation",GradientOperation)
#cv2.imshow("erosion",erosion)
#cv2.imshow("opening",opening)
cv2.imshow("opening",opening)

#cv2.imshow("orignal",image)
#cv2.imshow("bilateral_filter",bilateral_filter)
#cv2.imshow("Blur",blur)

# translation zooming,flipping,perception operation

cv2.waitKey(0)
cv2.destroyAllWindows()import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io
import cv2

url="https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg"
imge = io.imread(url)

image = np.array(imge)

print("The loaded image is of type:",type(image))
print("The loaded image is of size:",image.shape)
print("intensity at index", image[50][50])

B,G,R = cv2.split(image)
#cv2.imshow("Image",image)
#cv2.imshow("B",B)
#cv2.imshow("G",G)
#cv2.imshow("R",R)

gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#cv2.imshow("Gray",gray)
hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
h,s,v=cv2.split(hsv)
hsv_equ=cv2.equalizeHist(v)
merge_hsv=cv2.merge((h,s,hsv_equ))
bgr_enhanced=cv2.cvtColor(merge_hsv,cv2.COLOR_HSV2BGR)

hist=cv2.calcHist([image],channels=[0],mask=None,histSize=[256],ranges=[0,255])
B_hist=cv2.calcHist([B],channels=[0],mask=None,histSize=[256],ranges=[0,255])
G_hist=cv2.calcHist([G],channels=[0],mask=None,histSize=[256],ranges=[0,255])
R_hist=cv2.calcHist([R],channels=[0],mask=None,histSize=[256],ranges=[0,255])

output=cv2.equalizeHist(gray)
output_clr=cv2.cvtColor(output,cv2.COLOR_GRAY2BGR)
color_enhanced = cv2.applyColorMap(gray, cv2.COLORMAP_JET)

#hsv_equ=cv2.equalizeHist(hsv)
cv2.imshow("BGR_ENH",bgr_enhanced)
cv2.imshow("Original",image)
cv2.imshow("gray_Enh",output)
#cv2.imshow("Output",np.hstack([gray, output]))
#cv2.imshow("hsv_value",hsv_equ)

image_hist=cv2.calcHist([output],channels=[0],mask=None,histSize=[256],ranges=[0,255])

plt.plot(B_hist)
plt.plot(G_hist)
plt.plot(R_hist)
#plt.plot(image_hist)
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

import cv2
import numpy as np
#image=cv2.imread(r"C:\Users\cheta\OneDrive\Desktop\depositphotos_74355965-stock-photo-beau
tiful-oak-at-the-sunset.jpg")
image=cv2.imread(r"C:\Users\cheta\OneDrive\Pictures\Camera
Roll\WIN_20230320_00_08_27_Pro.jpg")

#video=cv2.VideoCapture(r"C:\Users\cheta\OneDrive\Pictures\Camera
Roll\WIN_20230823_16_29_45_Pro.mp4")
#success,image=video.read()
#while success:
# success,image=video.read()
# frame=cv2.resize(image,(680,700))
#cv2.imshow("VIDEO",frame)

# if cv2.waitKey(1)==27:
# break

gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

## Bluring
blur=cv2.blur(image,(5,5))
gaussian_blur = cv2.GaussianBlur(image, (5, 5), 2)
median_blur = cv2.medianBlur(image, 7)
bilateral_filter = cv2.bilateralFilter(image, 9, 75, 75) ## Bluring while preserving the edges

# Resize
# Resize the image to a new width and height
gray = cv2.resize(gray, (600, 600))

# Cropping
# Define the coordinates of the ROI
x, y, w, h = 100, 50, 200, 900

cropped = image[y:y+h, x:x+w]

# Rotation
# Get the image center
h,w = (image.shape[:2])

center=(h/2,w/2)
# Define the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1 )
# Apply the rotation
rotated = cv2.warpAffine(image, rotation_matrix, (952, 830 ))

# Flipping the Image
flipped_horizontal=cv2.flip(image,1)

# Morphological Transformation
kernal=np.ones((5,5))
erosion=cv2.erode(gray,kernal,iterations=1)# ek black to sare balck , will consider white only if
surrounding is also white
dilate=cv2.dilate(gray,kernal,iterations=1)# Ek white to sare white
opening=cv2.morphologyEx(gray,cv2.MORPH_OPEN,kernal)# Errosion then Dilation TO reduce
Noise
closing=cv2.morphologyEx(gray,cv2.MORPH_CLOSE,kernal)#dilation then erosion # image ko
bharne ke liye
GradientOperation=cv2.morphologyEx(gray,cv2.MORPH_GRADIENT,kernal)#Dilation - Erode,Mote
- Patla Outline OF The Object
TOP_HAT=cv2.morphologyEx(gray,cv2.MORPH_TOPHAT,kernal)#input-Opening Heighlight minor
detaion in the image only
cv2.imshow("GradientOperation",GradientOperation)
#cv2.imshow("erosion",erosion)
#cv2.imshow("opening",opening)
cv2.imshow("opening",opening)

#cv2.imshow("orignal",image)
#cv2.imshow("bilateral_filter",bilateral_filter)
#cv2.imshow("Blur",blur)

# translation zooming,flipping,perception operation

cv2.waitKey(0)
cv2.destroyAllWindows()
